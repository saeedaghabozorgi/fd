# %%
# import libraries test 1
import boto3, re, sys, math, json, os, sagemaker, urllib.request
from sagemaker import get_execution_role
import numpy as np                                
import pandas as pd                               
import matplotlib.pyplot as plt                   
from IPython.display import Image                 
from IPython.display import display               
from time import gmtime, strftime                 
from sagemaker.predictor import csv_serializer   
import io
import time
import json
import sagemaker.amazon.common as smac
# %matplotlib inline
# Define IAM role
role = get_execution_role()
prefix = 'pred-bank-enroll/sagemaker/DEMO-xgboost-dm'
containers = {'us-west-2': '433757028032.dkr.ecr.us-west-2.amazonaws.com/xgboost:latest',
              'us-east-1': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest',
              'us-east-2': '825641698319.dkr.ecr.us-east-2.amazonaws.com/xgboost:latest',
              'eu-west-1': '685385470294.dkr.ecr.eu-west-1.amazonaws.com/xgboost:latest'} # each region has its XGBoost container
my_region = boto3.session.Session().region_name # set the region of the instance


print("Success - the MySageMakerInstance is in the " + my_region + " region. You will use the " + containers[my_region] + " container for your SageMaker endpoint.")
# Out:
# Success - the MySageMakerInstance is in the us-east-1 region. You will use the 811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest container for your SageMaker endpoint.

# %%
role
# Out:
# 'arn:aws:iam::079329190341:role/service-role/AmazonSageMaker-ExecutionRole-20190404T141667'

# %%
bucket_name = 'demo-saeed'
prefix = 'fraudcredit-local'
dataset_name = 'creditcard.csv'
data_location = 's3://{}/{}/{}'.format(bucket_name, prefix,dataset_name)

# %%
data = pd.read_csv(data_location)
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4 -0.206010  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
from sklearn.preprocessing import StandardScaler
data['normAmount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))
data = data.drop(['Time','Amount'],axis=1)
data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10     ...           V21       V22       V23  \
# 0  0.098698  0.363787  0.090794     ...     -0.018307  0.277838 -0.110474
# 1  0.085102 -0.255425 -0.166974     ...     -0.225775 -0.638672  0.101288
# 2  0.247676 -1.514654  0.207643     ...      0.247998  0.771679  0.909412
# 3  0.377436 -1.387024 -0.054952     ...     -0.108300  0.005274 -0.190321
# 4 -0.270533  0.817739  0.753074     ...     -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28  Class  normAmount
# 0  0.066928  0.128539 -0.189115  0.133558 -0.021053      0    0.244964
# 1 -0.339846  0.167170  0.125895 -0.008983  0.014724      0   -0.342475
# 2 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752      0    1.160686
# 3 -1.175575  0.647376 -0.221929  0.062723  0.061458      0    0.140534
# 4  0.141267 -0.206010  0.502292  0.219422  0.215153      0   -0.073403
#
# [5 rows x 30 columns]

# %%
X = data.loc[:, data.columns != 'Class']
y = data.loc[:, data.columns == 'Class']

# %%
# Number of data points in the minority class
number_records_fraud = len(data[data.Class == 1])
fraud_indices = np.array(data[data.Class == 1].index)

# Picking the indices of the normal classes
normal_indices = data[data.Class == 0].index

# Out of the indices we picked, randomly select "x" number (number_records_fraud)
random_normal_indices = np.random.choice(normal_indices, number_records_fraud, replace = False)
random_normal_indices = np.array(random_normal_indices)

# Appending the 2 indices
under_sample_indices = np.concatenate([fraud_indices,random_normal_indices])

# Under sample dataset
under_sample_data = data.iloc[under_sample_indices,:]

X_undersample = under_sample_data.loc[:, under_sample_data.columns != 'Class']
y_undersample = under_sample_data.loc[:, under_sample_data.columns == 'Class']

# Showing ratio
print("Percentage of normal transactions: ", len(under_sample_data[under_sample_data.Class == 0])/len(under_sample_data))
print("Percentage of fraud transactions: ", len(under_sample_data[under_sample_data.Class == 1])/len(under_sample_data))
print("Total number of transactions in resampled data: ", len(under_sample_data))
# Out:
# Percentage of normal transactions:  0.5
# Percentage of fraud transactions:  0.5
# Total number of transactions in resampled data:  984

# %%
from sklearn.cross_validation import train_test_split

# Whole dataset
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3, random_state = 0)

print("Number transactions train dataset: ", len(X_train))
print("Number transactions test dataset: ", len(X_test))
print("Total number of transactions: ", len(X_train)+len(X_test))

# Undersampled dataset
X_train_undersample, X_test_undersample, y_train_undersample, y_test_undersample = train_test_split(X_undersample
                                                                                                   ,y_undersample
                                                                                                   ,test_size = 0.3
                                                                                                   ,random_state = 0)
print("")
print("Number transactions train dataset: ", len(X_train_undersample))
print("Number transactions test dataset: ", len(X_test_undersample))
print("Total number of transactions: ", len(X_train_undersample)+len(X_test_undersample))
# Out:
# Number transactions train dataset:  199364
# Number transactions test dataset:  85443
# Total number of transactions:  284807
#
# Number transactions train dataset:  688
# Number transactions test dataset:  296
# Total number of transactions:  984
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
f = io.BytesIO()
smac.write_numpy_to_dense_tensor(f, X_train_undersample.values.astype('float32'), y_train_undersample.values.reshape(-1).astype('float32'))
f.seek(0)
boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix, 'train','linear_train2.data')).upload_fileobj(f)

# %%
# #s3_input_train = sagemaker.s3_input(s3_data='s3://{}/{}/train'.format(bucket_name, prefix), content_type='csv')
s3_input_train = sagemaker.s3_input(s3_data='s3://{}/{}/train'.format(bucket_name, prefix))
s3_input_train.config
# Out:
# {'DataSource': {'S3DataSource': {'S3DataDistributionType': 'FullyReplicated',
#    'S3DataType': 'S3Prefix',
#    'S3Uri': 's3://demo-saeed/fraudcredit-local/train'}}}

# %%
test_file = 'linear_test.data'

f = io.BytesIO()
smac.write_numpy_to_dense_tensor(f, X_test_undersample.values.astype('float32'), y_test_undersample.values.reshape(-1).astype('float32'))
f.seek(0)

boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix, 'test',test_file)).upload_fileobj(f)
s3_input_test = sagemaker.s3_input(s3_data='s3://{}/{}/test'.format(bucket_name, prefix))

# %%
s3_input_test.config
# Out:
# {'DataSource': {'S3DataSource': {'S3DataDistributionType': 'FullyReplicated',
#    'S3DataType': 'S3Prefix',
#    'S3Uri': 's3://demo-saeed/fraudcredit-local/test'}}}

# %% [markdown]
# # training

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
container = get_image_uri(boto3.Session().region_name, 'linear-learner')

# %%
container
# Out:
# '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner:1'

# %%
output_location = 's3://{}/{}/output'.format(bucket_name, prefix)
print('training artifacts will be uploaded to: {}'.format(output_location))
# Out:
# training artifacts will be uploaded to: s3://demo-saeed/fraudcredit-local/output

# %%
X_train_undersample.shape
# Out:
# (688, 29)

# %%
import boto3
import sagemaker

sess = sagemaker.Session()

linear = sagemaker.estimator.Estimator(container,
                                       role, 
                                       train_instance_count=1, 
                                       train_instance_type='ml.c4.xlarge',
                                       output_path=output_location,
                                       sagemaker_session=sess)
linear.set_hyperparameters(feature_dim=29,
                           predictor_type='binary_classifier',
                           mini_batch_size=20)

linear.fit({'train': s3_input_train})
# Out:
# 2019-05-19 04:54:24 Starting - Starting the training job...
# 2019-05-19 04:54:26 Starting - Launching requested ML instances.........
# 2019-05-19 04:55:59 Starting - Preparing the instances for training.........
# 2019-05-19 04:57:46 Downloading - Downloading input data
# 2019-05-19 04:57:46 Training - Training image download completed. Training in progress.
# Docker entrypoint called with argument(s): train
# [05/19/2019 04:57:49 INFO 139753719244608] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [05/19/2019 04:57:49 INFO 139753719244608] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'29', u'mini_batch_size': u'20', u'predictor_type': u'binary_classifier'}
# [05/19/2019 04:57:49 INFO 139753719244608] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'29', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'20', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [05/19/2019 04:57:49 WARNING 139753719244608] Loggers have already been setup.
# Process 1 is a worker.
# [05/19/2019 04:57:49 INFO 139753719244608] Using default worker.
# [2019-05-19 04:57:49.540] [tensorio] [info] batch={"data_pipeline": "/opt/ml/input/data/train", "num_examples": 20, "features": [{"name": "label_values", "shape": [1], "storage_type": "dense"}, {"name": "values", "shape": [29], "storage_type": "dense"}]}
# [2019-05-19 04:57:49.554] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 0, "duration": 13, "num_examples": 1}
# [05/19/2019 04:57:49 INFO 139753719244608] Create Store: local
# [2019-05-19 04:57:49.643] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 1, "duration": 88, "num_examples": 35}
# [05/19/2019 04:57:49 INFO 139753719244608] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f1a9ea17ad0>
# [05/19/2019 04:57:49 INFO 139753719244608] Scaling model computed with parameters:
#  {'stdev_weight':
# [ 5.37093401  3.51423669  6.05505562  3.15990615  4.16107321  1.72736216
#   5.50474882  4.75488472  2.27321959  4.39149952  2.77775979  4.57568741
#   1.07245505  4.65953684  0.97884095  3.48016787  6.05121374  2.46887565
#   1.26017797  0.94291687  2.74739146  1.14399672  1.25995207  0.58030087
#   0.68885964  0.46805999  0.91067994  0.42479756  0.85678345]
# <NDArray 29 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [
"Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1558241870.718466}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5248043130425846, "sum": 0.5248043130425846, "min": 0.5248043130425846}}, "EndTime": 1558241870.718533, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1558241870.718523}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5473427442943348, "sum": 0.5473427442943348, "min": 0.5473427442943348}}, "EndTime": 1558241870.718585, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1558241870.71857}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4355184800484601, "sum": 0.4355184800484601, "min": 0.4355184800484601}}, "EndTime": 1558241870.718648, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1558241870.718632}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4366257394061369, "sum": 0.4366257394061369, "min": 0.4366257394061369}}, "EndTime": 1558241870.718711, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1558241870.718695}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4274385781849132, "sum": 0.4274385781849132, "min": 0.4274385781849132}}, "EndTime": 1558241870.718769, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1558241870.718753}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4272316203397863, "sum": 0.4272316203397863, "min": 0.4272316203397863}}, "EndTime": 1558241870.718832, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1558241870.718815}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6841770817251767, "sum": 0.6841770817251767, "min": 0.6841770817251767}}, "EndTime": 1558241870.71889, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1558241870.718874}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6932134670369765, "sum": 0.6932134670369765, "min": 0.6932134670369765}}, "EndTime": 1558241870.718952, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1558241870.718936}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6857490118812112, "sum": 0.6857490118812112, "min": 0.6857490118812112}}, "EndTime": 1558241870.719015, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1558241870.718999}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6859328676672543, "sum": 0.6859328676672543, "min": 0.6859328676672543}}, "EndTime": 1558241870.719071, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1558241870.719056}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7103049264234655, "sum": 0.7103049264234655, "min": 0.7103049264234655}}, "EndTime": 1558241870.719128, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1558241870.719112}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7097275327233707, "sum": 0.7097275327233707, "min": 0.7097275327233707}}, "EndTime": 1558241870.719191, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1558241870.719175}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7063236587187823, "sum": 0.7063236587187823, "min": 0.7063236587187823}}, "EndTime": 1558241870.719248, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1558241870.719232}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7110939053928151, "sum": 0.7110939053928151, "min": 0.7110939053928151}}, "EndTime": 1558241870.719309, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1558241870.719293}
#
# [05/19/2019 04:57:50 INFO 139753719244608] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.48368383646
# [05/19/2019 04:57:50 INFO 139753719244608] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.262103843601
# [05/19/2019 04:57:50 INFO 139753719244608] Epoch 0: Loss improved. Updating best model
# [05/19/2019 04:57:50 INFO 139753719244608] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 35, "sum": 35.0, "min": 35}, "Number of Batches Since Last Reset": {"count": 1, "max": 35, "sum": 35.0, "min": 35}, "Number of Records Since Last Reset": {"count": 1, "max": 688, "sum": 688.0, "min": 688}, "Total Batches Seen": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Total Records Seen": {"count": 1, "max": 1396, "sum": 1396.0, "min": 1396}, "Max Records Seen Between Resets": {"count": 1, "max": 688, "sum": 688.0, "min": 688}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1558241870.722338, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1558241869.751877}
#
# [05/19/2019 04:57:50 INFO 139753719244608] #throughput_metric: host=algo-1, train throughput=708.857559895 records/second
# [2019-05-19 04:57:50.722] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 2, "duration": 970, "num_examples": 35}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3385773974306443, "sum": 0.3385773974306443, "min": 0.3385773974306443}}, "EndTime": 1558241871.811938, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1558241871.811846}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.35532399626339184, "sum": 0.35532399626339184, "min": 0.35532399626339184}}, "EndTime": 1558241871.812063, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1558241871.812045}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.35155816078186036, "sum": 0.35155816078186036, "min": 0.35155816078186036}}, "EndTime": 1558241871.812121, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1558241871.812107}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3569835410398595, "sum": 0.3569835410398595, "min": 0.3569835410398595}}, "EndTime": 1558241871.812167, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1558241871.812155}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1817371381118017, "sum": 0.1817371381118017, "min": 0.1817371381118017}}, "EndTime": 1558241871.812212, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1558241871
"Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1558241871.813416}
#
# [05/19/2019 04:57:51 INFO 139753719244608] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.338577397431
# [05/19/2019 04:57:51 INFO 139753719244608] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.176763139621
# [05/19/2019 04:57:51 INFO 139753719244608] Epoch 1: Loss improved. Updating best model
# [05/19/2019 04:57:51 INFO 139753719244608] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 35, "sum": 35.0, "min": 35}, "Number of Batches Since Last Reset": {"count": 1, "max": 35, "sum": 35.0, "min": 35}, "Number of Records Since Last Reset": {"count": 1, "max": 688, "sum": 688.0, "min": 688}, "Total Batches Seen": {"count": 1, "max": 106, "sum": 106.0, "min": 106}, "Total Records Seen": {"count": 1, "max": 2084, "sum": 2084.0, "min": 2084}, "Max Records Seen Between Resets": {"count": 1, "max": 688, "sum": 688.0, "min": 688}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1558241871.817262, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1558241870.722631}
#
# [05/19/2019 04:57:51 INFO 139753719244608] #throughput_metric: host=algo-1, train throughput=628.449373093 records/second
# [2019-05-19 04:57:51.817] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 3, "duration": 1094, "num_examples": 35}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.29086879456744474, "sum": 0.29086879456744474, "min": 0.29086879456744474}}, "EndTime": 1558241872.968225, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.968166}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.30062387725886175, "sum": 0.30062387725886175, "min": 0.30062387725886175}}, "EndTime": 1558241872.968308, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.96829}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3001526678309721, "sum": 0.3001526678309721, "min": 0.3001526678309721}}, "EndTime": 1558241872.968366, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.968351}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3018913100747501, "sum": 0.3018913100747501, "min": 0.3018913100747501}}, "EndTime": 1558241872.968431, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.968417}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.16054171893526525, "sum": 0.16054171893526525, "min": 0.16054171893526525}}, "EndTime": 1558241872.968486, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.96847}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.16514962772455286, "sum": 0.16514962772455286, "min": 0.16514962772455286}}, "EndTime": 1558241872.96854, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.968525}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.16533264817998689, "sum": 0.16533264817998689, "min": 0.16533264817998689}}, "EndTime": 1558241872.968603, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.968585}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1642623187316691, "sum": 0.1642623187316691, "min": 0.1642623187316691}}, "EndTime": 1558241872.968667, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.96865}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3000807495678172, "sum": 0.3000807495678172, "min": 0.3000807495678172}}, "EndTime": 1558241872.96873, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.968713}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.28459556207937353, "sum": 0.28459556207937353, "min": 0.28459556207937353}}, "EndTime": 1558241872.968797, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.96878}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.31574456271003276, "sum": 0.31574456271003276, "min": 0.31574456271003276}}, "EndTime": 1558241872.968865, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.968847}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.29206618982202864, "sum": 0.29206618982202864, "min": 0.29206618982202864}}, "EndTime": 1558241872.968942, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.968915}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.17713765501976014, "sum": 0.17713765501976014, "min": 0.17713765501976014}}, "EndTime": 1558241872.968999, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.968984}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.17774983017760165, "sum": 0.17774983017760165, "min": 0.17774983017760165}}, "EndTime": 1558241872.96905, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.969039}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.17918740458348217, "sum": 0.17918740458348217, "min": 0.17918740458348217}}, "EndTime": 1558241872.969079, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.969072}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1797771006822586, "sum": 0.1797771006822586, "min": 0.1797771006822586}}, "EndTime": 1558241872.969132, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.969116}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.41345742379917816, "sum": 0.41345742379917816, "min": 0.41345742379917816}}, "EndTime": 1558241872.969198, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.969181}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.41269369335735545, "sum": 0.41269369335735545, "min": 0.41269369335735545}}, "EndTime": 1558241872.969262, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.969245}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4134837627410889, "sum": 0.4134837627410889, "min": 0.4134837627410889}}, "EndTime": 1558241872.969316, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.969301}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.413895442906548, "sum": 0.413895442906548, "min": 0.413895442906548}}, "EndTime": 1558241872.969379, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.969363}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4224658902953653, "sum": 0.4224658902953653, "min": 0.4224658902953653}}, "EndTime": 1558241872.969434, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.969419}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4234006194507374, "sum": 0.4234006194507374, "min": 0.4234006194507374}}, "EndTime": 1558241872.96949, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.969479}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4229586054297054, "sum": 0.4229586054297054, "min": 0.4229586054297054}}, "EndTime": 1558241872.96954, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.969528}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.42342606993282544, "sum": 0.42342606993282544, "min": 0.42342606993282544}}, "EndTime": 1558241872.969586, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.969576}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6826823515050552, "sum": 0.6826823515050552, "min": 0.6826823515050552}}, "EndTime": 1558241872.969625, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.969613}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6827152883305269, "sum": 0.6827152883305269, "min": 0.6827152883305269}}, "EndTime": 1558241872.969687, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.969671}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6826518970377305, "sum": 0.6826518970377305, "min": 0.6826518970377305}}, "EndTime": 1558241872.969752, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.969735}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6827850271673763, "sum": 0.6827850271673763, "min": 0.6827850271673763}}, "EndTime": 1558241872.969815, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.969799}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7053651080412023, "sum": 0.7053651080412023, "min": 0.7053651080412023}}, "EndTime": 1558241872.96987, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.969855}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6959638357162475, "sum": 0.6959638357162475, "min": 0.6959638357162475}}, "EndTime": 1558241872.969927, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.969912}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.698093879924101, "sum": 0.698093879924101, "min": 0.698093879924101}}, "EndTime": 1558241872.969982, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.969966}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6976710347568288, "sum": 0.6976710347568288, "min": 0.6976710347568288}}, "EndTime": 1558241872.970037, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241872.970022}
#
# [05/19/2019 04:57:52 INFO 139753719244608] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.290868794567
# [05/19/2019 04:57:52 INFO 139753719244608] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.160541718935
# [05/19/2019 04:57:52 INFO 139753719244608] Epoch 2: Loss improved. Updating best model
# [05/19/2019 04:57:52 INFO 139753719244608] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 35, "sum": 35.0, "min": 35}, "Number of Batches Since Last Reset": {"count": 1, "max": 35, "sum": 35.0, "min": 35}, "Number of Records Since Last Reset": {"count": 1, "max": 688, "sum": 688.0, "min": 688}, "Total Batches Seen": {"count": 1, "max": 141, "sum": 141.0, "min": 141}, "Total Records Seen": {"count": 1, "max": 2772, "sum": 2772.0, "min": 2772}, "Max Records Seen Between Resets": {"count": 1, "max": 688, "sum": 688.0, "min": 688}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1558241872.972559, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1558241871.817525}
#
# [05/19/2019 04:57:52 INFO 139753719244608] #throughput_metric: host=algo-1, train throughput=595.594784853 records/second
# [2019-05-19 04:57:52.972] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 4, "duration": 1155, "num_examples": 35}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.26445031937430885, "sum": 0.26445031937430885, "min": 0.26445031937430885}}, "EndTime": 1558241873.929746, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1558241873.929687}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.2708717191920561, "sum": 0.2708717191920561, "min": 0.2708717191920561}}, "EndTime": 1558241873.929827, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1558241873.929809}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.27231144309043886, "sum": 0.27231144309043886, "min": 0.27231144309043886}}, "EndTime": 1558241873.929889, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1558241873.929872}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.27182587034562056, "sum": 0.27182587034562056, "min": 0.27182587034562056}}, "EndTime": 1558241873.929951, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1558241873.929934}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1624001361320124, "sum": 0.1624001361320124, "min": 0.1624001361320124}}, "EndTime": 1558241873.93001, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 
"Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1558241884.55576}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6827771481345681, "sum": 0.6827771481345681, "min": 0.6827771481345681}}, "EndTime": 1558241884.555839, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1558241884.555823}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6819556418587179, "sum": 0.6819556418587179, "min": 0.6819556418587179}}, "EndTime": 1558241884.555897, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1558241884.555881}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6829619351555319, "sum": 0.6829619351555319, "min": 0.6829619351555319}}, "EndTime": 1558241884.555969, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1558241884.555952}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.702506667024949, "sum": 0.702506667024949, "min": 0.702506667024949}}, "EndTime": 1558241884.556003, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1558241884.555995}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6932030719869277, "sum": 0.6932030719869277, "min": 0.6932030719869277}}, "EndTime": 1558241884.556029, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1558241884.556022}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7044256883509019, "sum": 0.7044256883509019, "min": 0.7044256883509019}}, "EndTime": 1558241884.556068, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1558241884.556056}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6938983861137838, "sum": 0.6938983861137838, "min": 0.6938983861137838}}, "EndTime": 1558241884.556097, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1558241884.55609}
#
# [05/19/2019 04:58:04 INFO 139753719244608] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy_objective <loss>=0.183394861747
# [05/19/2019 04:58:04 INFO 139753719244608] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_cross_entropy_objective, value=0.139661963076
# [05/19/2019 04:58:04 INFO 139753719244608] Epoch 14: Loss improved. Updating best model
# [05/19/2019 04:58:04 INFO 139753719244608] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 35, "sum": 35.0, "min": 35}, "Number of Batches Since Last Reset": {"count": 1, "max": 35, "sum": 35.0, "min": 35}, "Number of Records Since Last Reset": {"count": 1, "max": 688, "sum": 688.0, "min": 688}, "Total Batches Seen": {"count": 1, "max": 561, "sum": 561.0, "min": 561}, "Total Records Seen": {"count": 1, "max": 11028, "sum": 11028.0, "min": 11028}, "Max Records Seen Between Resets": {"count": 1, "max": 688, "sum": 688.0, "min": 688}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1558241884.55883, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1558241883.599725}
#
# [05/19/2019 04:58:04 INFO 139753719244608] #throughput_metric: host=algo-1, train throughput=717.256078522 records/second
# [05/19/2019 04:58:04 WARNING 139753719244608] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [05/19/2019 04:58:04 WARNING 139753719244608] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2019-05-19 04:58:04.559] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 16, "duration": 959, "num_examples": 35}
# [2019-05-19 04:58:04.559] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 17, "duration": 0, "num_examples": 1}
# [2019-05-19 04:58:04.706] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 18, "duration": 144, "num_examples": 35}
# [05/19/2019 04:58:04 INFO 139753719244608] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.12738916754376056)
# [05/19/2019 04:58:04 INFO 139753719244608] #train_score (algo-1) : ('binary_classification_accuracy', 0.95494186046511631)
# [05/19/2019 04:58:04 INFO 139753719244608] #train_score (algo-1) : ('binary_f_1.000', 0.9532428355957768)
# [05/19/2019 04:58:04 INFO 139753719244608] #train_score (algo-1) : ('precision', 0.9937106918238994)
# [05/19/2019 04:58:04 INFO 139753719244608] #train_score (algo-1) : ('recall', 0.9159420289855073)
# [05/19/2019 04:58:04 INFO 139753719244608] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.127389167544
# [05/19/2019 04:58:04 INFO 139753719244608] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.954941860465
# [05/19/2019 04:58:04 INFO 139753719244608] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.953242835596
# [05/19/2019 04:58:04 INFO 139753719244608] #quality_metric: host=algo-1, train precision <score>=0.993710691824
# [05/19/2019 04:58:04 INFO 139753719244608] #quality_metric: host=algo-1, train recall <score>=0.915942028986
# [05/19/2019 04:58:04 INFO 139753719244608] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 1e-05}
# [05/19/2019 04:58:04 INFO 139753719244608] Saved checkpoint to "/tmp/tmptL19XV/mx-mod-0000.params"
# [05/19/2019 04:58:04 INFO 139753719244608] Test data is not provided.
# [2019-05-19 04:58:04.793] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 19, "duration": 86, "num_examples": 35}
# [2019-05-19 04:58:04.793] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "duration": 15127, "num_epochs": 20, "num_examples": 632}
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 15344.023942947388, "sum": 15344.023942947388, "min": 15344.023942947388}, "finalize.time": {"count": 1, "max": 225.233793258667, "sum": 225.233793258667, "min": 225.233793258667}, "initialize.time": {"count": 1, "max": 210.2360725402832, "sum": 210.2360725402832, "min": 210.2360725402832}, "check_early_stopping.time": {"count": 15, "max": 1.0280609130859375, "sum": 12.528419494628906, "min": 0.7598400115966797}, "setuptime": {"count": 1, "max": 19.324064254760742, "sum": 19.324064254760742, "min": 19.324064254760742}, "update.time": {"count": 15, "max": 1154.893159866333, "sum": 14800.77338218689, "min": 921.1859703063965}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1558241884.793288, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1558241869.538477}
#
#
# 2019-05-19 04:58:13 Uploading - Uploading generated training model
# 2019-05-19 04:58:13 Completed - Training job completed
# Billable seconds: 44

# %%
linear.output_path
# Out:
# 's3://demo-saeed/fraudcredit-local/output'

# %%
#linear.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
linear_predictor = linear.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# ---------------------------------------------------------------------------------------------------!

# %%
from sagemaker.predictor import csv_serializer, json_deserializer

linear_predictor.content_type = 'text/csv'
linear_predictor.serializer = csv_serializer
linear_predictor.deserializer = json_deserializer
linear_predictor.predict(X_test.iloc[0])
# Out:
# {'predictions': [{'score': 0.12841635942459106, 'predicted_label': 0.0}]}

# %%
linear_predictor.endpoint
# Out:
# 'linear-learner-2019-05-19-04-54-24-797'

# %%
input_Data = ",".join( map( str, X_test.iloc[0] ) )
input_Data
# Out:
# '-0.32333357234920695,1.05745524547602,-0.0483411518056082,-0.607204308469926,1.25982114985563,-0.0917607168463734,1.15910149881154,-0.12433460579324301,-0.174639536425237,-1.6444006451833897,-1.11886302116203,0.202647309859633,1.14596494837297,-1.80235955648842,-0.24717793192731197,-0.0609453515056588,0.846605737903167,0.379454386602278,0.8472622447749741,0.186409421250743,-0.20709826694548397,-0.43389027235615096,-0.261613282942462,-0.0466506062633096,0.211512300497807,0.00829721213659597,0.108494430085674,0.161139166913704,-0.19330594520930533'

# %%
import io
import boto3
import json
import csv

# grab environment variables
ENDPOINT_NAME = 'linear-learner-2019-05-19-04-54-24-797'
runtime= boto3.client('runtime.sagemaker')

input_Data = ",".join( map( str, X_test.iloc[0] ) )
response = runtime.invoke_endpoint(EndpointName=ENDPOINT_NAME,
                                   ContentType='text/csv',
                                   Body=input_Data)
print(response)
result = json.loads(response['Body'].read().decode())
print(result)
# Out:
# {'ResponseMetadata': {'RequestId': 'afced8f0-b989-4e56-866f-05bd57535d49', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'afced8f0-b989-4e56-866f-05bd57535d49', 'x-amzn-invoked-production-variant': 'AllTraffic', 'date': 'Sun, 19 May 2019 21:03:51 GMT', 'content-type': 'application/json', 'content-length': '73'}, 'RetryAttempts': 0}, 'ContentType': 'application/json', 'InvokedProductionVariant': 'AllTraffic', 'Body': <botocore.response.StreamingBody object at 0x7ff5d51be198>}
# {'predictions': [{'score': 0.12841635942459106, 'predicted_label': 0.0}]}
