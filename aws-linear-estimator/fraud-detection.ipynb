# %%
# import libraries
import boto3, re, sys, math, json, os, sagemaker, urllib.request
from sagemaker import get_execution_role
import numpy as np                                
import pandas as pd                               
import matplotlib.pyplot as plt                   
from IPython.display import Image                 
from IPython.display import display               
from time import gmtime, strftime                 
from sagemaker.predictor import csv_serializer   
import io
import time
import json
import sagemaker.amazon.common as smac
# %matplotlib inline
# Define IAM role
role = get_execution_role()
prefix = 'pred-bank-enroll/sagemaker/DEMO-xgboost-dm'
containers = {'us-west-2': '433757028032.dkr.ecr.us-west-2.amazonaws.com/xgboost:latest',
              'us-east-1': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest',
              'us-east-2': '825641698319.dkr.ecr.us-east-2.amazonaws.com/xgboost:latest',
              'eu-west-1': '685385470294.dkr.ecr.eu-west-1.amazonaws.com/xgboost:latest'} # each region has its XGBoost container


print("Success - the MySageMakerInstance is in the " + my_region + " region. You will use the " + containers[my_region] + " container for your SageMaker endpoint.")
# Out:
# Success - the MySageMakerInstance is in the us-east-1 region. You will use the 811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest container for your SageMaker endpoint.

# %%
role
# Out:
# 'arn:aws:iam::079329190341:role/service-role/AmazonSageMaker-ExecutionRole-20190404T141667'

# %%
bucket_name = 'demo-saeed'
prefix = 'fraudcredit-local'
dataset_name = 'creditcard.csv'
data_location = 's3://{}/{}/{}'.format(bucket_name, prefix,dataset_name)

# %%
data = pd.read_csv(data_location)
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4 -0.206010  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
from sklearn.preprocessing import StandardScaler
data['normAmount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))
data = data.drop(['Time','Amount'],axis=1)
data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10     ...           V21       V22       V23  \
# 0  0.098698  0.363787  0.090794     ...     -0.018307  0.277838 -0.110474
# 1  0.085102 -0.255425 -0.166974     ...     -0.225775 -0.638672  0.101288
# 2  0.247676 -1.514654  0.207643     ...      0.247998  0.771679  0.909412
# 3  0.377436 -1.387024 -0.054952     ...     -0.108300  0.005274 -0.190321
# 4 -0.270533  0.817739  0.753074     ...     -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28  Class  normAmount
# 0  0.066928  0.128539 -0.189115  0.133558 -0.021053      0    0.244964
# 1 -0.339846  0.167170  0.125895 -0.008983  0.014724      0   -0.342475
# 2 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752      0    1.160686
# 3 -1.175575  0.647376 -0.221929  0.062723  0.061458      0    0.140534
# 4  0.141267 -0.206010  0.502292  0.219422  0.215153      0   -0.073403
#
# [5 rows x 30 columns]

# %%
X = data.loc[:, data.columns != 'Class']
y = data.loc[:, data.columns == 'Class']

# %%
def generate():
    # Number of data points in the minority class
    number_records_fraud = len(data[data.Class == 1])
    fraud_indices = np.array(data[data.Class == 1].index)

    # Picking the indices of the normal classes
    normal_indices = data[data.Class == 0].index

    # Out of the indices we picked, randomly select "x" number (number_records_fraud)
    random_normal_indices = np.random.choice(normal_indices, number_records_fraud, replace = False)
    random_normal_indices = np.array(random_normal_indices)

    # Appending the 2 indices
    under_sample_indices = np.concatenate([fraud_indices,random_normal_indices])

    # Under sample dataset
    under_sample_data = data.iloc[under_sample_indices,:]

    X_undersample = under_sample_data.loc[:, under_sample_data.columns != 'Class']
    y_undersample = under_sample_data.loc[:, under_sample_data.columns == 'Class']
    return (X_undersample,y_undersample)

# %%
def big_df_generator():
    df_x,df_y = generate()
    for i in range(1000):
        df1_x,df1_y = generate()
        df_x = df_x.append(df1_x)
        df_y = df_y.append(df1_y)
    return df_x,df_y

# %% [markdown]
# ### write training data into s3

# %%
for i in range(3):
    print(i)
    train_file = 'linear_train'+str(i)+'.data'
    big_df_x,big_df_y = big_df_generator()

    f = io.BytesIO()
    smac.write_numpy_to_dense_tensor(f, big_df_x.values.astype('float32'), big_df_y.values.reshape(-1).astype('float32'))
    f.seek(0)

    boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix, 'train',train_file)).upload_fileobj(f)
# Out:
# 0
# 1

# %%
#s3_input_train = sagemaker.s3_input(s3_data='s3://{}/{}/train'.format(bucket_name, prefix), content_type='csv')
s3_input_train = sagemaker.s3_input(s3_data='s3://{}/{}/train'.format(bucket_name, prefix))
s3_input_train.config
# Out:
# {'DataSource': {'S3DataSource': {'S3DataDistributionType': 'FullyReplicated',
#    'S3DataType': 'S3Prefix',
#    'S3Uri': 's3://demo-saeed/fraudcredit-local/train'}}}

# %%
# f = io.BytesIO()
# smac.write_numpy_to_dense_tensor(f, X_train_undersample.values.astype('float32'), y_train_undersample.values.reshape(-1).astype('float32'))
# f.seek(0)
# boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix, 'train','linear_train2.data')).upload_fileobj(f)

# %%
s3_input_train.config
# Out:
# {'DataSource': {'S3DataSource': {'S3DataDistributionType': 'FullyReplicated',
#    'S3DataType': 'S3Prefix',
#    'S3Uri': 's3://demo-saeed/fraudcredit-local/train'}}}

# %%
test_file = 'linear_test.data'

f = io.BytesIO()
smac.write_numpy_to_dense_tensor(f, X_test_undersample.values.astype('float32'), y_test_undersample.values.reshape(-1).astype('float32'))
f.seek(0)

boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix, 'test',test_file)).upload_fileobj(f)
s3_input_test = sagemaker.s3_input(s3_data='s3://{}/{}/test'.format(bucket_name, prefix))

# %%
s3_input_test.config
# Out:
# {'DataSource': {'S3DataSource': {'S3DataDistributionType': 'FullyReplicated',
#    'S3DataType': 'S3Prefix',
#    'S3Uri': 's3://demo-saeed/fraudcredit-local/test'}}}

# %%
s3_input_test

# %%
# boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix, 'train/train.csv')).upload_file('train.csv')
# s3_input_train = sagemaker.s3_input(s3_data='s3://{}/{}/train'.format(bucket_name, prefix), content_type='csv')

# %% [markdown]
# # training

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
container = get_image_uri(boto3.Session().region_name, 'linear-learner')

# %%
container
# Out:
# '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner:1'

# %%
output_location = 's3://{}/{}/output'.format(bucket_name, prefix)
print('training artifacts will be uploaded to: {}'.format(output_location))
# Out:
# training artifacts will be uploaded to: s3://demo-saeed/fraudcredit-local/output

# %%
X_train_undersample.shape
# Out:
# (688, 29)

# %%
import boto3
import sagemaker

sess = sagemaker.Session()

linear = sagemaker.estimator.Estimator(container,
                                       role, 
                                       train_instance_count=1, 
                                       train_instance_type='ml.c4.xlarge',
                                       output_path=output_location,
                                       sagemaker_session=sess)
linear.set_hyperparameters(feature_dim=29,
                           predictor_type='binary_classifier',
                           mini_batch_size=20)

linear.fit({'train': s3_input_train})
# Out:
# INFO:sagemaker:Creating training-job with name: linear-learner-2019-05-15-15-15-12-499
# 2019-05-15 15:15:12 Starting - Starting the training job...
# 2019-05-15 15:15:16 Starting - Launching requested ML instances......
# 2019-05-15 15:16:27 Starting - Preparing the instances for training.........
# 2019-05-15 15:18:02 Downloading - Downloading input data..
# Docker entrypoint called with argument(s): train
# [05/15/2019 15:18:21 INFO 140114638452544] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [05/15/2019 15:18:21 INFO 140114638452544] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'29', u'mini_batch_size': u'20', u'predictor_type': u'binary_classifier'}
# [05/15/2019 15:18:21 INFO 140114638452544] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'29', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'20', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [05/15/2019 15:18:21 WARNING 140114638452544] Loggers have already been setup.
# Process 1 is a worker.
# [05/15/2019 15:18:21 INFO 140114638452544] Using default worker.
# [2019-05-15 15:18:21.779] [tensorio] [info] batch={"data_pipeline": "/opt/ml/input/data/train", "num_examples": 20, "features": [{"name": "label_values", "shape": [1], "storage_type": "dense"}, {"name": "values", "shape": [29], "storage_type": "dense"}]}
# [2019-05-15 15:18:21.793] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 0, "duration": 15, "num_examples": 1}
# [05/15/2019 15:18:21 INFO 140114638452544] Create Store: local
# [2019-05-15 15:18:21.999] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 1, "duration": 205, "num_examples": 69}
# [05/15/2019 15:18:21 INFO 140114638452544] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f6e9f15aad0>
# [05/15/2019 15:18:22 INFO 140114638452544] Scaling model computed with parameters:
#  {'stdev_weight':
# [ 5.39638472  3.56157351  5.99194574  3.16979051  4.18178701  1.75238955
#   5.52651691  4.74446392  2.3097589   4.39735413  2.81138039  4.54258776
#   1.11003172  4.69434023  0.94187766  3.47722077  6.06403017  2.46221018
#   1.28058577  1.04660213  2.74611998  1.15591204  1.29353201  0.57238561
#   0.68253273  0.45757431  0.91680622  0.42085153  1.07227802]
# <NDArray 29 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [ -2.36287093e+00   1.78778327e+00  -3.53604388e+00   2.24708223e+00
#   -1.59319496e+00  -6.99274659e-01  -2.73254943e+00   3.69068265e-01
#   -1.23649502e+00  -2.81130505e+00   1.88036466e+00  -3.19854593e+00
#   -2.45991088e-02  -3.51522565e+00  -1.87929149e-03  -2.13371682e+00
#   -3.40313840e+00  -1.13107860e+00   3.81991386e-01   1.52480975e-01
"Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557933504.13421}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4248460205162273, "sum": 0.4248460205162273, "min": 0.4248460205162273}}, "EndTime": 1557933504.134287, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557933504.13427}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.684053946943844, "sum": 0.684053946943844, "min": 0.684053946943844}}, "EndTime": 1557933504.134346, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557933504.134331}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6884572351680083, "sum": 0.6884572351680083, "min": 0.6884572351680083}}, "EndTime": 1557933504.134402, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557933504.134388}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6839253937496859, "sum": 0.6839253937496859, "min": 0.6839253937496859}}, "EndTime": 1557933504.134478, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557933504.134462}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6840546762242037, "sum": 0.6840546762242037, "min": 0.6840546762242037}}, "EndTime": 1557933504.134533, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557933504.134517}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7146934698609745, "sum": 0.7146934698609745, "min": 0.7146934698609745}}, "EndTime": 1557933504.134588, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557933504.134572}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7028175858890309, "sum": 0.7028175858890309, "min": 0.7028175858890309}}, "EndTime": 1557933504.13465, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557933504.134634}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7020376969786252, "sum": 0.7020376969786252, "min": 0.7020376969786252}}, "EndTime": 1557933504.134706, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557933504.13469}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7050529346746557, "sum": 0.7050529346746557, "min": 0.7050529346746557}}, "EndTime": 1557933504.134768, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557933504.134751}
#
# [05/15/2019 15:18:24 INFO 140114638452544] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.410693852691
# [05/15/2019 15:18:24 INFO 140114638452544] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.236197264887
# [05/15/2019 15:18:24 INFO 140114638452544] Epoch 0: Loss improved. Updating best model
# [05/15/2019 15:18:24 INFO 140114638452544] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 69, "sum": 69.0, "min": 69}, "Number of Batches Since Last Reset": {"count": 1, "max": 69, "sum": 69.0, "min": 69}, "Number of Records Since Last Reset": {"count": 1, "max": 1376, "sum": 1376.0, "min": 1376}, "Total Batches Seen": {"count": 1, "max": 139, "sum": 139.0, "min": 139}, "Total Records Seen": {"count": 1, "max": 2772, "sum": 2772.0, "min": 2772}, "Max Records Seen Between Resets": {"count": 1, "max": 1376, "sum": 1376.0, "min": 1376}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1557933504.137878, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1557933502.138988}
#
# [05/15/2019 15:18:24 INFO 140114638452544] #throughput_metric: host=algo-1, train throughput=688.338646602 records/second
# [2019-05-15 15:18:24.138] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 2, "duration": 1999, "num_examples": 69}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.2793216494952931, "sum": 0.2793216494952931, "min": 0.2793216494952931}}, "EndTime": 1557933506.06666, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.066589}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.2871673343812718, "sum": 0.2871673343812718, "min": 0.2871673343812718}}, "EndTime": 1557933506.066739, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.066726}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.2887785222600488, "sum": 0.2887785222600488, "min": 0.2887785222600488}}, "EndTime": 1557933506.066779, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.066766}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.2890670371406219, "sum": 0.2890670371406219, "min": 0.2890670371406219}}, "EndTime": 1557933506.06683, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.066816}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.18160681520753047, "sum": 0.18160681520753047, "min": 0.18160681520753047}}, "EndTime": 1557933506.066884, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.066873}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.18523662841933616, "sum": 0.18523662841933616, "min": 0.18523662841933616}}, "EndTime": 1557933506.06694, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.066928}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1809789363075705, "sum": 0.1809789363075705, "min": 0.1809789363075705}}, "EndTime": 1557933506.066991, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.066978}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.18442573251531405, "sum": 0.18442573251531405, "min": 0.18442573251531405}}, "EndTime": 1557933506.067028, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.067019}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.2887314291561351, "sum": 0.2887314291561351, "min": 0.2887314291561351}}, "EndTime": 1557933506.067075, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.06706}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.2758532552158131, "sum": 0.2758532552158131, "min": 0.2758532552158131}}, "EndTime": 1557933506.067115, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.067106}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.301623757797129, "sum": 0.301623757797129, "min": 0.301623757797129}}, "EndTime": 1557933506.067163, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.067148}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.28028654421077054, "sum": 0.28028654421077054, "min": 0.28028654421077054}}, "EndTime": 1557933506.06721, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.0672}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.19658442849622054, "sum": 0.19658442849622054, "min": 0.19658442849622054}}, "EndTime": 1557933506.067249, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.067237}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.19934822342851582, "sum": 0.19934822342851582, "min": 0.19934822342851582}}, "EndTime": 1557933506.067301, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.067286}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.19699570413898018, "sum": 0.19699570413898018, "min": 0.19699570413898018}}, "EndTime": 1557933506.067354, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.06733}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.19940004655543495, "sum": 0.19940004655543495, "min": 0.19940004655543495}}, "EndTime": 1557933506.067405, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.06739}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.41472242334309745, "sum": 0.41472242334309745, "min": 0.41472242334309745}}, "EndTime": 1557933506.067465, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.067449}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4143637310056125, "sum": 0.4143637310056125, "min": 0.4143637310056125}}, "EndTime": 1557933506.067521, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.067505}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4146841701339273, "sum": 0.4146841701339273, "min": 0.4146841701339273}}, "EndTime": 1557933506.06757, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.067556}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.41500283514752107, "sum": 0.41500283514752107, "min": 0.41500283514752107}}, "EndTime": 1557933506.067626, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.067611}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4224542123429916, "sum": 0.4224542123429916, "min": 0.4224542123429916}}, "EndTime": 1557933506.06768, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.067665}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.42314793467521666, "sum": 0.42314793467521666, "min": 0.42314793467521666}}, "EndTime": 1557933506.067735, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.06772}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.422822102729012, "sum": 0.422822102729012, "min": 0.422822102729012}}, "EndTime": 1557933506.067788, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.067773}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4231652091531193, "sum": 0.4231652091531193, "min": 0.4231652091531193}}, "EndTime": 1557933506.067841, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.067828}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6824576924828922, "sum": 0.6824576924828922, "min": 0.6824576924828922}}, "EndTime": 1557933506.067888, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.067874}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6824484137927784, "sum": 0.6824484137927784, "min": 0.6824484137927784}}, "EndTime": 1557933506.06794, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.067926}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6823967554989983, "sum": 0.6823967554989983, "min": 0.6823967554989983}}, "EndTime": 1557933506.067994, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.067979}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6826118469238281, "sum": 0.6826118469238281, "min": 0.6826118469238281}}, "EndTime": 1557933506.068054, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.068037}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7196048666449154, "sum": 0.7196048666449154, "min": 0.7196048666449154}}, "EndTime": 1557933506.068108, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.068093}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6994081041392158, "sum": 0.6994081041392158, "min": 0.6994081041392158}}, "EndTime": 1557933506.068158, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.068146}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7044717283809886, "sum": 0.7044717283809886, "min": 0.7044717283809886}}, "EndTime": 1557933506.068215, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.0682}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7010873345767751, "sum": 0.7010873345767751, "min": 0.7010873345767751}}, "EndTime": 1557933506.068256, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1557933506.068247}
#
# [05/15/2019 15:18:26 INFO 140114638452544] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.279321649495
# [05/15/2019 15:18:26 INFO 140114638452544] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.180978936308
# [05/15/2019 15:18:26 INFO 140114638452544] Epoch 1: Loss improved. Updating best model
# [05/15/2019 15:18:26 INFO 140114638452544] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 69, "sum": 69.0, "min": 69}, "Number of Batches Since Last Reset": {"count": 1, "max": 69, "sum": 69.0, "min": 69}, "Number of Records Since Last Reset": {"count": 1, "max": 1376, "sum": 1376.0, "min": 1376}, "Total Batches Seen": {"count": 1, "max": 208, "sum": 208.0, "min": 208}, "Total Records Seen": {"count": 1, "max": 4148, "sum": 4148.0, "min": 4148}, "Max Records Seen Between Resets": {"count": 1, "max": 1376, "sum": 1376.0, "min": 1376}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 
"Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557933508.280168}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6826156777494093, "sum": 0.6826156777494093, "min": 0.6826156777494093}}, "EndTime": 1557933508.280203, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557933508.280197}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7244269946042229, "sum": 0.7244269946042229, "min": 0.7244269946042229}}, "EndTime": 1557933508.280247, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557933508.280233}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6990792302524342, "sum": 0.6990792302524342, "min": 0.6990792302524342}}, "EndTime": 1557933508.280275, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557933508.280268}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.71620113288655, "sum": 0.71620113288655, "min": 0.71620113288655}}, "EndTime": 1557933508.280299, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557933508.280292}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7010583274504718, "sum": 0.7010583274504718, "min": 0.7010583274504718}}, "EndTime": 1557933508.280322, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557933508.280316}
#
# [05/15/2019 15:18:28 INFO 140114638452544] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.243489057877
# [05/15/2019 15:18:28 INFO 140114638452544] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.174468530254
# [05/15/2019 15:18:28 INFO 140114638452544] Epoch 2: Loss improved. Updating best model
# [05/15/2019 15:18:28 INFO 140114638452544] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 69, "sum": 69.0, "min": 69}, "Number of Batches Since Last Reset": {"count": 1, "max": 69, "sum": 69.0, "min": 69}, "Number of Records Since Last Reset": {"count": 1, "max": 1376, "sum": 1376.0, "min": 1376}, "Total Batches Seen": {"count": 1, "max": 277, "sum": 277.0, "min": 277}, "Total Records Seen": {"count": 1, "max": 5524, "sum": 5524.0, "min": 5524}, "Max Records Seen Between Resets": {"count": 1, "max": 1376, "sum": 1376.0, "min": 1376}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1557933508.284258, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1557933506.071181}
#
# [05/15/2019 15:18:28 INFO 140114638452544] #throughput_metric: host=algo-1, train throughput=621.721093454 records/second
# [2019-05-15 15:18:28.284] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 4, "duration": 2213, "num_examples": 69}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.22411682395374075, "sum": 0.22411682395374075, "min": 0.22411682395374075}}, "EndTime": 1557933510.335637, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557933510.335533}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.22489843780503554, "sum": 0.22489843780503554, "min": 0.22489843780503554}}, "EndTime": 1557933510.33575, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557933510.335729}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.23004332833430347, "sum": 0.23004332833430347, "min": 0.23004332833430347}}, "EndTime": 1557933510.336047, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557933510.336023}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.22600646141697378, "sum": 0.22600646141697378, "min": 0.22600646141697378}}, "EndTime": 1557933510.336154, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557933510.336104}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.17064394885126283, "sum": 0.17064394885126283, "min": 0.17064394885126283}}, "EndTime": 1557933510.336231, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557933510.336214}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1781842912273372, "sum": 0.1781842912273372, "min": 0.1781842912273372}}, "EndTime": 1557933510.336317, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557933510.336272}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1703086070058977, "sum": 0.1703086070058977, "min": 0.1703086070058977}}, "EndTime": 1557933510.33638, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557933510.336363}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.17780843529411974, "sum": 0.17780843529411974, "min": 0.17780843529411974}}, "EndTime": 1557933510.336434, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1557933510.336419}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.16669782612691908, "sum": 0.16669782612691908, "min": 0.16669782612691908}}, "EndTime": 1557933531.873337, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.873325}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1754228356129983, "sum": 0.1754228356129983, "min": 0.1754228356129983}}, "EndTime": 1557933531.873393, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.873378}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.16701725666575573, "sum": 0.16701725666575573, "min": 0.16701725666575573}}, "EndTime": 1557933531.87345, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.873434}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1555142723462161, "sum": 0.1555142723462161, "min": 0.1555142723462161}}, "EndTime": 1557933531.873514, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.873498}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.173569845791687, "sum": 0.173569845791687, "min": 0.173569845791687}}, "EndTime": 1557933531.873578, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.873561}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.15507553064209573, "sum": 0.15507553064209573, "min": 0.15507553064209573}}, "EndTime": 1557933531.873626, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.873611}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.173537852242589, "sum": 0.173537852242589, "min": 0.173537852242589}}, "EndTime": 1557933531.873675, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.87366}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.18413348942995073, "sum": 0.18413348942995073, "min": 0.18413348942995073}}, "EndTime": 1557933531.87373, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.873715}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.17835781780235907, "sum": 0.17835781780235907, "min": 0.17835781780235907}}, "EndTime": 1557933531.873781, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.873767}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.18645471921738457, "sum": 0.18645471921738457, "min": 0.18645471921738457}}, "EndTime": 1557933531.873832, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.873818}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.17817619530593648, "sum": 0.17817619530593648, "min": 0.17817619530593648}}, "EndTime": 1557933531.873887, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.873872}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1806391568744884, "sum": 0.1806391568744884, "min": 0.1806391568744884}}, "EndTime": 1557933531.873949, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.873933}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.19863733767586597, "sum": 0.19863733767586597, "min": 0.19863733767586597}}, "EndTime": 1557933531.874007, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.873994}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.18069360392058598, "sum": 0.18069360392058598, "min": 0.18069360392058598}}, "EndTime": 1557933531.874059, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.874045}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1985363546101486, "sum": 0.1985363546101486, "min": 0.1985363546101486}}, "EndTime": 1557933531.874112, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.874097}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4134172106490416, "sum": 0.4134172106490416, "min": 0.4134172106490416}}, "EndTime": 1557933531.874172, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.874156}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.41515674065141117, "sum": 0.41515674065141117, "min": 0.41515674065141117}}, "EndTime": 1557933531.874217, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.874203}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.413395167799557, "sum": 0.413395167799557, "min": 0.413395167799557}}, "EndTime": 1557933531.87427, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.874255}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.41516436408547797, "sum": 0.41516436408547797, "min": 0.41516436408547797}}, "EndTime": 1557933531.874326, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.874311}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.41404666164342097, "sum": 0.41404666164342097, "min": 0.41404666164342097}}, "EndTime": 1557933531.874377, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.874362}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.42017106343718136, "sum": 0.42017106343718136, "min": 0.42017106343718136}}, "EndTime": 1557933531.874431, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.874417}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4140092208104975, "sum": 0.4140092208104975, "min": 0.4140092208104975}}, "EndTime": 1557933531.874484, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.874469}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4201143229708952, "sum": 0.4201143229708952, "min": 0.4201143229708952}}, "EndTime": 1557933531.874531, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.87452}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6813111424446106, "sum": 0.6813111424446106, "min": 0.6813111424446106}}, "EndTime": 1557933531.874581, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.874568}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6825550990946153, "sum": 0.6825550990946153, "min": 0.6825550990946153}}, "EndTime": 1557933531.874633, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.874617}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6813024093123043, "sum": 0.6813024093123043, "min": 0.6813024093123043}}, "EndTime": 1557933531.874684, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.87467}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.682605267272276, "sum": 0.682605267272276, "min": 0.682605267272276}}, "EndTime": 1557933531.874745, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.87473}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6897809842053582, "sum": 0.6897809842053582, "min": 0.6897809842053582}}, "EndTime": 1557933531.874798, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.874784}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7145316874279696, "sum": 0.7145316874279696, "min": 0.7145316874279696}}, "EndTime": 1557933531.874856, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.874842}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.690032020035912, "sum": 0.690032020035912, "min": 0.690032020035912}}, "EndTime": 1557933531.874901, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.874887}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7176214007770314, "sum": 0.7176214007770314, "min": 0.7176214007770314}}, "EndTime": 1557933531.874954, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933531.874939}
#
# [05/15/2019 15:18:51 INFO 140114638452544] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy_objective <loss>=0.173329940614
# [05/15/2019 15:18:51 INFO 140114638452544] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_cross_entropy_objective, value=0.155075530642
# [05/15/2019 15:18:51 INFO 140114638452544] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 69, "sum": 69.0, "min": 69}, "Number of Batches Since Last Reset": {"count": 1, "max": 69, "sum": 69.0, "min": 69}, "Number of Records Since Last Reset": {"count": 1, "max": 1376, "sum": 1376.0, "min": 1376}, "Total Batches Seen": {"count": 1, "max": 1105, "sum": 1105.0, "min": 1105}, "Total Records Seen": {"count": 1, "max": 22036, "sum": 22036.0, "min": 22036}, "Max Records Seen Between Resets": {"count": 1, "max": 1376, "sum": 1376.0, "min": 1376}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1557933531.876903, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1557933529.906304}
#
# [05/15/2019 15:18:51 INFO 140114638452544] #throughput_metric: host=algo-1, train throughput=698.225498766 records/second
# [05/15/2019 15:18:51 WARNING 140114638452544] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [05/15/2019 15:18:51 WARNING 140114638452544] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2019-05-15 15:18:51.877] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 16, "duration": 1970, "num_examples": 69}
# [2019-05-15 15:18:51.877] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 17, "duration": 0, "num_examples": 1}
# [2019-05-15 15:18:52.078] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 18, "duration": 197, "num_examples": 69}
# [05/15/2019 15:18:52 INFO 140114638452544] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.14090425995460085)
# [05/15/2019 15:18:52 INFO 140114638452544] #train_score (algo-1) : ('binary_classification_accuracy', 0.94040697674418605)
# [05/15/2019 15:18:52 INFO 140114638452544] #train_score (algo-1) : ('binary_f_1.000', 0.9388971684053651)
# [05/15/2019 15:18:52 INFO 140114638452544] #train_score (algo-1) : ('precision', 0.9662576687116564)
# [05/15/2019 15:18:52 INFO 140114638452544] #train_score (algo-1) : ('recall', 0.9130434782608695)
# [05/15/2019 15:18:52 INFO 140114638452544] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.140904259955
# [05/15/2019 15:18:52 INFO 140114638452544] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.940406976744
# [05/15/2019 15:18:52 INFO 140114638452544] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.938897168405
# [05/15/2019 15:18:52 INFO 140114638452544] #quality_metric: host=algo-1, train precision <score>=0.966257668712
# [05/15/2019 15:18:52 INFO 140114638452544] #quality_metric: host=algo-1, train recall <score>=0.913043478261
# [05/15/2019 15:18:52 INFO 140114638452544] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 0.0001}
# [05/15/2019 15:18:52 INFO 140114638452544] Saved checkpoint to "/tmp/tmpU0I5Am/mx-mod-0000.params"
# [05/15/2019 15:18:52 INFO 140114638452544] Test data is not provided.
# [2019-05-15 15:18:52.249] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 19, "duration": 171, "num_examples": 69}
# [2019-05-15 15:18:52.249] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "duration": 30317, "num_epochs": 20, "num_examples": 1244}
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 30556.051015853882, "sum": 30556.051015853882, "min": 30556.051015853882}, "finalize.time": {"count": 1, "max": 364.78614807128906, "sum": 364.78614807128906, "min": 364.78614807128906}, "initialize.time": {"count": 1, "max": 358.9589595794678, "sum": 358.9589595794678, "min": 358.9589595794678}, "check_early_stopping.time": {"count": 15, "max": 1.154184341430664, "sum": 12.236356735229492, "min": 0.186920166015625}, "setuptime": {"count": 1, "max": 15.311002731323242, "sum": 15.311002731323242, "min": 15.311002731323242}, "update.time": {"count": 15, "max": 2212.8829956054688, "sum": 29731.507778167725, "min": 1920.2969074249268}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1557933532.249739, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1557933501.77645}
#
#
# 2019-05-15 15:18:59 Uploading - Uploading generated training model
# 2019-05-15 15:18:59 Completed - Training job completed
# Billable seconds: 58

# %%
linear.output_path
# Out:
# 's3://demo-saeed/fraudcredit-local/output'

# %%
linear.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# INFO:sagemaker:Creating model with name: linear-learner-2019-04-30-16-37-31-231
# INFO:sagemaker:Creating endpoint with name linear-learner-2019-04-30-16-28-35-773
# ---------------------------------------------------------------------------------------!

# %%
linear.deploy()
